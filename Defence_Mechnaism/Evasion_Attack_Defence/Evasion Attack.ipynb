# %%
# MNIST Evasion Attack and Defense
# ================================
#
# This notebook demonstrates evasion attacks against an MNIST digit classifier
# and applies defense strategies to improve model robustness.

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, Input, Lambda
from tensorflow.keras.utils import to_categorical
import os
import time

# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Create directories for saving models and results
os.makedirs("models", exist_ok=True)
os.makedirs("results", exist_ok=True)

print("TensorFlow version:", tf.__version__)

# 1. Load and prepare the MNIST dataset
# =====================================

print("\n1. Loading MNIST dataset...")
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values to be between 0 and 1
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Reshape to include channel dimension (MNIST is grayscale, so 1 channel)
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# Convert class labels to one-hot encoding
y_train_cat = to_categorical(y_train, 10)
y_test_cat = to_categorical(y_test, 10)

print(f"Training data shape: {x_train.shape}")
print(f"Test data shape: {x_test.shape}")

# 2. Define and train a CNN model for MNIST
# =========================================

def build_basic_model():
    """Build a simple CNN for MNIST digit classification"""
    model = Sequential([
        # First convolutional layer
        Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)),
        MaxPooling2D(pool_size=(2, 2)),
        
        # Second convolutional layer
        Conv2D(64, kernel_size=(3, 3), activation='relu'),
        MaxPooling2D(pool_size=(2, 2)),
        
        # Fully connected layers
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.2),
        Dense(10, activation='softmax')
    ])
    
    # Compile model
    model.compile(
        loss='categorical_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
    )
    
    return model

# First check if we have a pre-trained model
model_path = "models/mnist_basic_model.h5"
if os.path.exists(model_path):
    print(f"\n2. Loading pre-trained model from {model_path}...")
    model = load_model(model_path)
else:
    print("\n2. Training basic MNIST model...")
    model = build_basic_model()
    
    # Train the model
    history = model.fit(
        x_train, y_train_cat,
        batch_size=128,
        epochs=5,
        verbose=1,
        validation_data=(x_test, y_test_cat)
    )
    
    # Save the model
    model.save(model_path)
    print(f"Model saved to {model_path}")

# Evaluate the model
test_loss, test_accuracy = model.evaluate(x_test, y_test_cat, verbose=0)
print(f"Test accuracy: {test_accuracy:.4f}")

# 3. Implement Fast Gradient Sign Method (FGSM) attack
# ===================================================

def fgsm_attack(model, image, label, epsilon=0.1):
    """
    Implement the Fast Gradient Sign Method attack.
    
    Args:
        model: The target model
        image: Input image to be perturbed (should have batch dimension)
        label: True label of the image (one-hot encoded)
        epsilon: Perturbation size
        
    Returns:
        Adversarial example
    """
    # Convert to tensor
    image_tensor = tf.convert_to_tensor(image, dtype=tf.float32)
    label_tensor = tf.convert_to_tensor(label, dtype=tf.float32)
    
    # Define gradient tape scope
    with tf.GradientTape() as tape:
        tape.watch(image_tensor)
        prediction = model(image_tensor)
        loss = tf.keras.losses.categorical_crossentropy(label_tensor, prediction)
    
    # Get gradient of the loss with respect to the input
    gradient = tape.gradient(loss, image_tensor)
    
    # Create perturbation using sign of gradient
    signed_gradient = tf.sign(gradient)
    
    # Create adversarial example
    adversarial_example = image_tensor + epsilon * signed_gradient
    
    # Make sure the adversarial example is in [0, 1] range
    adversarial_example = tf.clip_by_value(adversarial_example, 0, 1)
    
    return adversarial_example.numpy()

def evaluate_attack(model, x_test, y_test, y_test_cat, epsilon=0.1, num_samples=100):
    """Evaluate the effectiveness of the FGSM attack"""
    
    # Choose a subset of test samples
    indices = np.random.choice(len(x_test), num_samples, replace=False)
    test_subset = x_test[indices]
    test_labels = y_test[indices]
    test_labels_cat = y_test_cat[indices]
    
    # Get predictions on original samples
    original_preds = model.predict(test_subset)
    original_preds_classes = np.argmax(original_preds, axis=1)
    
    # Keep only correctly classified samples
    correct_indices = np.where(original_preds_classes == test_labels)[0]
    correct_samples = test_subset[correct_indices]
    correct_labels = test_labels[correct_indices]
    correct_labels_cat = test_labels_cat[correct_indices]
    
    if len(correct_samples) == 0:
        print("No correctly classified samples found. Aborting attack evaluation.")
        return None, None, None, 0, []
    
    # Generate adversarial examples for correctly classified samples
    adversarial_examples = []
    for img, label in zip(correct_samples, correct_labels_cat):
        adversarial_example = fgsm_attack(model, np.expand_dims(img, axis=0), np.expand_dims(label, axis=0), epsilon)
        adversarial_examples.append(adversarial_example[0])
    
    adversarial_examples = np.array(adversarial_examples)
    
    # Get predictions on adversarial examples
    adv_preds = model.predict(adversarial_examples)
    adv_preds_classes = np.argmax(adv_preds, axis=1)
    
    # Calculate attack success rate (percentage of successful adversarial examples)
    attack_success = np.mean(adv_preds_classes != correct_labels)
    
    # Identify successful examples for visualization
    successful_indices = np.where(adv_preds_classes != correct_labels)[0]
    
    # Prepare visualization data
    vis_data = []
    for i in successful_indices[:5]:  # Pick up to 5 successful examples
        vis_data.append({
            'original': correct_samples[i],
            'adversarial': adversarial_examples[i],
            'original_class': correct_labels[i],
            'adversarial_class': adv_preds_classes[i]
        })
    
    return correct_samples, adversarial_examples, adv_preds_classes, attack_success, vis_data

print("\n3. Implementing FGSM attack...")

# Try with different epsilon values
epsilons = [0.01, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3]
attack_results = []

for epsilon in epsilons:
    print(f"\nTesting with epsilon = {epsilon}:")
    
    original_samples, adversarial_examples, adv_predictions, success_rate, vis_data = evaluate_attack(
        model, x_test, y_test, y_test_cat, epsilon=epsilon, num_samples=100
    )
    
    attack_results.append({
        'epsilon': epsilon,
        'success_rate': success_rate
    })
    
    print(f"Attack success rate: {success_rate:.4f}")
    
    # Visualize examples for the mid epsilon value
    if epsilon == 0.1 and vis_data:
        # Display original vs adversarial examples
        plt.figure(figsize=(15, 6))
        for i, example in enumerate(vis_data):
            # Original
            plt.subplot(2, 5, i+1)
            plt.imshow(example['original'].reshape(28, 28), cmap='gray')
            plt.title(f"Original: {example['original_class']}")
            plt.axis('off')
            
            # Adversarial
            plt.subplot(2, 5, i+6)
            plt.imshow(example['adversarial'].reshape(28, 28), cmap='gray')
            plt.title(f"Adversarial: {example['adversarial_class']}")
            plt.axis('off')
            
        plt.tight_layout()
        plt.savefig("results/adversarial_examples.png")
        plt.show()

# Plot attack success rate vs epsilon
plt.figure(figsize=(10, 6))
plt.plot([r['epsilon'] for r in attack_results], [r['success_rate'] for r in attack_results], 'bo-')
plt.xlabel('Epsilon')
plt.ylabel('Attack Success Rate')
plt.title('FGSM Attack Success Rate vs. Epsilon')
plt.grid(True)
plt.savefig("results/attack_success_vs_epsilon.png")
plt.show()

# 4. Implement Defense Strategies
# ==============================

# 4.1 Adversarial Training
# ----------------------

def generate_adversarial_training_data(model, x_train, y_train_cat, epsilon=0.1, ratio=0.5):
    """Generate adversarial examples for training"""
    print(f"Generating adversarial training data with epsilon={epsilon}")
    
    # Determine how many samples to augment
    num_adv_samples = int(len(x_train) * ratio)
    indices = np.random.choice(len(x_train), num_adv_samples, replace=False)
    
    x_train_subset = x_train[indices]
    y_train_cat_subset = y_train_cat[indices]
    
    # Generate adversarial examples
    adv_examples = []
    for i in range(0, len(x_train_subset), 100):  # Process in batches to save memory
        end_idx = min(i + 100, len(x_train_subset))
        batch_x = x_train_subset[i:end_idx]
        batch_y = y_train_cat_subset[i:end_idx]
        
        # Loop through each sample in the batch
        for j in range(len(batch_x)):
            if j % 1000 == 0:
                print(f"  Generating adversarial example {i+j+1}/{num_adv_samples}")
            
            # Generate adversarial example
            adv_example = fgsm_attack(
                model, 
                np.expand_dims(batch_x[j], axis=0), 
                np.expand_dims(batch_y[j], axis=0), 
                epsilon
            )
            adv_examples.append(adv_example[0])
    
    adv_examples = np.array(adv_examples)
    
    # Combine original and adversarial examples
    x_adv_train = np.concatenate([x_train, adv_examples])
    y_adv_train_cat = np.concatenate([y_train_cat, y_train_cat_subset])
    
    return x_adv_train, y_adv_train_cat

print("\n4.1 Implementing Adversarial Training defense...")

# Generate adversarial training data
x_adv_train, y_adv_train_cat = generate_adversarial_training_data(
    model, x_train, y_train_cat, epsilon=0.1, ratio=0.2
)

# Train a new model with adversarial examples
print("Training model with adversarial examples...")
adv_trained_model = build_basic_model()

adv_history = adv_trained_model.fit(
    x_adv_train, y_adv_train_cat,
    batch_size=128,
    epochs=5,
    verbose=1,
    validation_data=(x_test, y_test_cat)
)

# Save the adversarially trained model
adv_model_path = "models/mnist_adv_trained_model.h5"
adv_trained_model.save(adv_model_path)
print(f"Adversarially trained model saved to {adv_model_path}")

# Evaluate the adversarially trained model
adv_test_loss, adv_test_accuracy = adv_trained_model.evaluate(x_test, y_test_cat, verbose=0)
print(f"Adversarially trained model - Test accuracy: {adv_test_accuracy:.4f}")

# Test the adversarially trained model against the FGSM attack
print("Testing adversarially trained model against FGSM attack...")
_, _, _, adv_success_rate, _ = evaluate_attack(
    adv_trained_model, x_test, y_test, y_test_cat, epsilon=0.1, num_samples=100
)
print(f"Attack success rate against adversarially trained model: {adv_success_rate:.4f}")

# 4.2 Input Preprocessing Defense
# ----------------------------

def build_model_with_preprocessing(input_shape=(28, 28, 1), preprocessing_fn=None):
    """Build a model with a preprocessing layer"""
    inputs = Input(shape=input_shape)
    
    # Add preprocessing layer if provided
    if preprocessing_fn:
        x = Lambda(preprocessing_fn)(inputs)
    else:
        x = inputs
    
    # Same architecture as the basic model
    x = Conv2D(32, kernel_size=(3, 3), activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Conv2D(64, kernel_size=(3, 3), activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.2)(x)
    outputs = Dense(10, activation='softmax')(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    
    model.compile(
        loss='categorical_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
    )
    
    return model

def gaussian_noise_preprocessing(images, noise_level=0.1):
    """Add Gaussian noise as preprocessing defense"""
    noisy_images = images + tf.random.normal(shape=tf.shape(images), mean=0.0, stddev=noise_level)
    return tf.clip_by_value(noisy_images, 0.0, 1.0)

def median_filter_preprocessing(images):
    """Apply median filter as preprocessing defense"""
    # Since TensorFlow doesn't have a direct median filter function,
    # we'll use a workaround with depthwise_conv2d to approximate it
    # For a real implementation, you might want to use tf.py_function to call scipy's median filter
    
    def median_filter_single_image(image):
        # Convert to use with tf.nn.depthwise_conv2d
        image = tf.expand_dims(image, 0)  # Add batch dimension
        
        # Use max pooling + min pooling to approximate median filter
        # This is a rough approximation; real median filter would be better
        max_pool = tf.nn.max_pool2d(image, ksize=3, strides=1, padding='SAME')
        min_pool = -tf.nn.max_pool2d(-image, ksize=3, strides=1, padding='SAME')
        
        # Average of min and max is a very rough approximation of median
        median_approx = (max_pool + min_pool) / 2.0
        
        return median_approx[0]  # Remove batch dimension
    
    return tf.map_fn(median_filter_single_image, images)

print("\n4.2 Implementing Input Preprocessing defense...")

# Define preprocessing functions for defense
noise_preprocessing = lambda x: gaussian_noise_preprocessing(x, noise_level=0.1)
gaussian_noise_model = build_model_with_preprocessing(preprocessing_fn=noise_preprocessing)

# Train model with Gaussian noise preprocessing
print("Training model with Gaussian noise preprocessing...")
noise_history = gaussian_noise_model.fit(
    x_train, y_train_cat,
    batch_size=128,
    epochs=5,
    verbose=1,
    validation_data=(x_test, y_test_cat)
)

# Save the preprocessing defense model
noise_model_path = "models/mnist_gaussian_noise_model.h5"
gaussian_noise_model.save(noise_model_path)
print(f"Gaussian noise preprocessing model saved to {noise_model_path}")

# Evaluate the noise preprocessing model
noise_test_loss, noise_test_accuracy = gaussian_noise_model.evaluate(x_test, y_test_cat, verbose=0)
print(f"Gaussian noise preprocessing model - Test accuracy: {noise_test_accuracy:.4f}")

# Test the preprocessing model against the FGSM attack
print("Testing Gaussian noise preprocessing model against FGSM attack...")
_, _, _, noise_success_rate, _ = evaluate_attack(
    gaussian_noise_model, x_test, y_test, y_test_cat, epsilon=0.1, num_samples=100
)
print(f"Attack success rate against Gaussian noise preprocessing model: {noise_success_rate:.4f}")

# 4.3 Ensemble Defense
# ------------------

def build_ensemble_model(model_list, input_shape=(28, 28, 1)):
    """Build an ensemble model that averages predictions from multiple models"""
    inputs = Input(shape=input_shape)
    
    # Get outputs from each model
    model_outputs = [model(inputs) for model in model_list]
    
    # Average the outputs
    ensemble_output = Lambda(lambda outputs: tf.reduce_mean(tf.stack(outputs, axis=0), axis=0))(model_outputs)
    
    # Create ensemble model
    ensemble_model = Model(inputs=inputs, outputs=ensemble_output)
    
    # Compile the model
    ensemble_model.compile(
        loss='categorical_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
    )
    
    return ensemble_model

print("\n4.3 Implementing Ensemble defense...")

# Create a diverse set of models for the ensemble
# Instead of training from scratch, we'll create variations of our existing models
print("Building ensemble from diverse models...")

ensemble_models = [
    model,  # Original model
    adv_trained_model,  # Adversarially trained model
    gaussian_noise_model  # Model with noise preprocessing
]

# Create and compile the ensemble model
ensemble_model = build_ensemble_model(ensemble_models)

# Evaluate the ensemble model
ensemble_test_loss, ensemble_test_accuracy = ensemble_model.evaluate(x_test, y_test_cat, verbose=0)
print(f"Ensemble model - Test accuracy: {ensemble_test_accuracy:.4f}")

# Test the ensemble model against the FGSM attack
print("Testing ensemble model against FGSM attack...")
_, _, _, ensemble_success_rate, _ = evaluate_attack(
    ensemble_model, x_test, y_test, y_test_cat, epsilon=0.1, num_samples=100
)
print(f"Attack success rate against ensemble model: {ensemble_success_rate:.4f}")

# 5. Compare all defenses
# =====================

print("\n5. Comparing all defenses...")

# Compare standard accuracy of all models
print("\nTest Accuracy:")
print(f"Basic model:                    {test_accuracy:.4f}")
print(f"Adversarially trained model:    {adv_test_accuracy:.4f}")
print(f"Gaussian noise defense model:   {noise_test_accuracy:.4f}")
print(f"Ensemble model:                 {ensemble_test_accuracy:.4f}")

# Compare attack success rates against all models
attack_success_rates = {}

# Basic model
_, _, _, basic_success_rate, _ = evaluate_attack(
    model, x_test, y_test, y_test_cat, epsilon=0.1, num_samples=100
)
attack_success_rates['Basic model'] = basic_success_rate

# We already have the other success rates from earlier steps
attack_success_rates['Adversarially trained model'] = adv_success_rate
attack_success_rates['Gaussian noise defense model'] = noise_success_rate
attack_success_rates['Ensemble model'] = ensemble_success_rate

print("\nFGSM Attack Success Rate (epsilon=0.1) - LOWER IS BETTER:")
for model_name, success_rate in attack_success_rates.items():
    print(f"{model_name}: {success_rate:.4f}")

# Plot comparison of model robustness
model_names = list(attack_success_rates.keys())
success_rates = [attack_success_rates[name] for name in model_names]

plt.figure(figsize=(12, 6))
bars = plt.bar(model_names, success_rates, color=['red', 'green', 'blue', 'purple'])

# Add values on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.01,
            f'{height:.4f}', ha='center', va='bottom')

plt.xlabel('Model')
plt.ylabel('Attack Success Rate (lower is better)')
plt.title('FGSM Attack Success Rate Against Different Defenses (epsilon=0.1)')
plt.ylim(0, max(success_rates) + 0.1)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.savefig("results/defense_comparison.png")
plt.show()

# 6. Test with different attack strengths
# =====================================

print("\n6. Testing models against different attack strengths...")

# Define epsilon values to test
test_epsilons = [0.01, 0.05, 0.1, 0.2, 0.3]

# Dictionary to store results for each model
model_results = {
    'Basic model': [],
    'Adversarially trained model': [],
    'Gaussian noise defense model': [],
    'Ensemble model': []
}

# Test each model against each epsilon value
for epsilon in test_epsilons:
    print(f"\nTesting with epsilon = {epsilon}")
    
    # Basic model
    _, _, _, basic_rate, _ = evaluate_attack(model, x_test, y_test, y_test_cat, 
                                            epsilon=epsilon, num_samples=100)
    model_results['Basic model'].append(basic_rate)
    
    # Adversarially trained model
    _, _, _, adv_rate, _ = evaluate_attack(adv_trained_model, x_test, y_test, y_test_cat, 
                                          epsilon=epsilon, num_samples=100)
    model_results['Adversarially trained model'].append(adv_rate)
    
    # Gaussian noise model
    _, _, _, noise_rate, _ = evaluate_attack(gaussian_noise_model, x_test, y_test, y_test_cat, 
                                            epsilon=epsilon, num_samples=100)
    model_results['Gaussian noise defense model'].append(noise_rate)
    
    # Ensemble model
    _, _, _, ensemble_rate, _ = evaluate_attack(ensemble_model, x_test, y_test, y_test_cat, 
                                              epsilon=epsilon, num_samples=100)
    model_results['Ensemble model'].append(ensemble_rate)

# Plot results
plt.figure(figsize=(12, 8))

# Plot line for each model
plt.plot(test_epsilons, model_results['Basic model'], 'ro-', label='Basic model')
plt.plot(test_epsilons, model_results['Adversarially trained model'], 'go-', label='Adversarially trained model')
plt.plot(test_epsilons, model_results['Gaussian noise defense model'], 'bo-', label='Gaussian noise defense model')
plt.plot(test_epsilons, model_results['Ensemble model'], 'mo-', label='Ensemble model')

plt.xlabel('Epsilon')
plt.ylabel('Attack Success Rate')
plt.title('Model Robustness Against FGSM Attacks of Varying Strength')
plt.grid(True, alpha=0.3)
plt.legend()
plt.savefig("results/model_robustness_comparison.png")
plt.show()

# 7. Conclusion
# ===========

print("\n7. Conclusion")
print("=" * 80)
print("This notebook demonstrated:")
print("1. Implementation of the FGSM adversarial attack against an MNIST classifier")
print("2. Three defense strategies:")
print("   - Adversarial Training: Including adversarial examples in training data")
print("   - Input Preprocessing: Adding Gaussian noise as a defensive measure")
print("   - Ensemble Defense: Combining multiple models for improved robustness")
print("\nFindings:")
print("- The basic model was highly vulnerable to adversarial examples")
print("- All defense strategies improved robustness to varying degrees")
print("- Adversarial training provided the most consistent defense across different attack strengths")
print("- The ensemble approach combined the strengths of individual defenses")
print("=" * 80)
# Out:
# 2025-04-10 01:48:39.605684: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-10 01:48:39.638676: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744246119.686457    7824 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744246119.701991    7824 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1744246119.739930    7824 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744246119.739983    7824 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744246119.739987    7824 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1744246119.739990    7824 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-10 01:48:39.751270: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# TensorFlow version: 2.19.0-rc0
#
# 1. Loading MNIST dataset...
# Training data shape: (60000, 28, 28, 1)
# Test data shape: (10000, 28, 28, 1)
#
# 2. Training basic MNIST model...
# /home/cybok/Desktop/cybok/cybokenv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-04-10 01:48:43.631351: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 29ms/step - accuracy: 0.8510 - loss: 0.4924 - val_accuracy: 0.9783 - val_loss: 0.0683
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.9789 - loss: 0.0678 - val_accuracy: 0.9849 - val_loss: 0.0495
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - accuracy: 0.9856 - loss: 0.0472 - val_accuracy: 0.9870 - val_loss: 0.0390
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 30ms/step - accuracy: 0.9885 - loss: 0.0374 - val_accuracy: 0.9888 - val_loss: 0.0359
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9918 - loss: 0.0278 - val_accuracy: 0.9895 - val_loss: 0.0339
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved to models/mnist_basic_model.h5
# Test accuracy: 0.9895
#
# 3. Implementing FGSM attack...
#
# Testing with epsilon = 0.01:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Attack success rate: 0.0102
#
# Testing with epsilon = 0.05:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Attack success rate: 0.0200
#
# Testing with epsilon = 0.1:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Attack success rate: 0.1134
# Testing with epsilon = 0.15:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Attack success rate: 0.3131
#
# Testing with epsilon = 0.2:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Attack success rate: 0.3700
#
# Testing with epsilon = 0.25:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Attack success rate: 0.7200
#
# Testing with epsilon = 0.3:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Attack success rate: 0.8061
# 4.1 Implementing Adversarial Training defense...
# Generating adversarial training data with epsilon=0.1
#   Generating adversarial example 1/12000
#   Generating adversarial example 101/12000
#   Generating adversarial example 201/12000
#   Generating adversarial example 301/12000
#   Generating adversarial example 401/12000
#   Generating adversarial example 501/12000
#   Generating adversarial example 601/12000
#   Generating adversarial example 701/12000
#   Generating adversarial example 801/12000
#   Generating adversarial example 901/12000
#   Generating adversarial example 1001/12000
#   Generating adversarial example 1101/12000
#   Generating adversarial example 1201/12000
#   Generating adversarial example 1301/12000
#   Generating adversarial example 1401/12000
#   Generating adversarial example 1501/12000
#   Generating adversarial example 1601/12000
#   Generating adversarial example 1701/12000
#   Generating adversarial example 1801/12000
#   Generating adversarial example 1901/12000
#   Generating adversarial example 2001/12000
#   Generating adversarial example 2101/12000
#   Generating adversarial example 2201/12000
#   Generating adversarial example 2301/12000
#   Generating adversarial example 2401/12000
#   Generating adversarial example 2501/12000
#   Generating adversarial example 2601/12000
#   Generating adversarial example 2701/12000
#   Generating adversarial example 2801/12000
#   Generating adversarial example 2901/12000
#   Generating adversarial example 3001/12000
#   Generating adversarial example 3101/12000
#   Generating adversarial example 3201/12000
#   Generating adversarial example 3301/12000
#   Generating adversarial example 3401/12000
#   Generating adversarial example 3501/12000
#   Generating adversarial example 3601/12000
#   Generating adversarial example 3701/12000
#   Generating adversarial example 3801/12000
#   Generating adversarial example 3901/12000
#   Generating adversarial example 4001/12000
#   Generating adversarial example 4101/12000
#   Generating adversarial example 4201/12000
#   Generating adversarial example 4301/12000
#   Generating adversarial example 4401/12000
#   Generating adversarial example 4501/12000
#   Generating adversarial example 4601/12000
#   Generating adversarial example 4701/12000
#   Generating adversarial example 4801/12000
#   Generating adversarial example 4901/12000
#   Generating adversarial example 5001/12000
#   Generating adversarial example 5101/12000
#   Generating adversarial example 5201/12000
#   Generating adversarial example 5301/12000
#   Generating adversarial example 5401/12000
#   Generating adversarial example 5501/12000
#   Generating adversarial example 5601/12000
#   Generating adversarial example 5701/12000
#   Generating adversarial example 5801/12000
#   Generating adversarial example 5901/12000
#   Generating adversarial example 6001/12000
#   Generating adversarial example 6101/12000
#   Generating adversarial example 6201/12000
#   Generating adversarial example 6301/12000
#   Generating adversarial example 6401/12000
#   Generating adversarial example 6501/12000
#   Generating adversarial example 6601/12000
#   Generating adversarial example 6701/12000
#   Generating adversarial example 6801/12000
#   Generating adversarial example 6901/12000
#   Generating adversarial example 7001/12000
#   Generating adversarial example 7101/12000
#   Generating adversarial example 7201/12000
#   Generating adversarial example 7301/12000
#   Generating adversarial example 7401/12000
#   Generating adversarial example 7501/12000
#   Generating adversarial example 7601/12000
#   Generating adversarial example 7701/12000
#   Generating adversarial example 7801/12000
#   Generating adversarial example 7901/12000
#   Generating adversarial example 8001/12000
#   Generating adversarial example 8101/12000
#   Generating adversarial example 8201/12000
#   Generating adversarial example 8301/12000
#   Generating adversarial example 8401/12000
#   Generating adversarial example 8501/12000
#   Generating adversarial example 8601/12000
#   Generating adversarial example 8701/12000
#   Generating adversarial example 8801/12000
#   Generating adversarial example 8901/12000
#   Generating adversarial example 9001/12000
#   Generating adversarial example 9101/12000
#   Generating adversarial example 9201/12000
#   Generating adversarial example 9301/12000
#   Generating adversarial example 9401/12000
#   Generating adversarial example 9501/12000
#   Generating adversarial example 9601/12000
#   Generating adversarial example 9701/12000
#   Generating adversarial example 9801/12000
#   Generating adversarial example 9901/12000
#   Generating adversarial example 10001/12000
#   Generating adversarial example 10101/12000
#   Generating adversarial example 10201/12000
#   Generating adversarial example 10301/12000
#   Generating adversarial example 10401/12000
#   Generating adversarial example 10501/12000
#   Generating adversarial example 10601/12000
#   Generating adversarial example 10701/12000
#   Generating adversarial example 10801/12000
#   Generating adversarial example 10901/12000
#   Generating adversarial example 11001/12000
#   Generating adversarial example 11101/12000
#   Generating adversarial example 11201/12000
#   Generating adversarial example 11301/12000
#   Generating adversarial example 11401/12000
#   Generating adversarial example 11501/12000
#   Generating adversarial example 11601/12000
#   Generating adversarial example 11701/12000
#   Generating adversarial example 11801/12000
#   Generating adversarial example 11901/12000
# Training model with adversarial examples...
# Epoch 1/5
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - accuracy: 0.8497 - loss: 0.4949 - val_accuracy: 0.9829 - val_loss: 0.0540
# Epoch 2/5
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.9740 - loss: 0.0845 - val_accuracy: 0.9876 - val_loss: 0.0365
# Epoch 3/5
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.9818 - loss: 0.0580 - val_accuracy: 0.9910 - val_loss: 0.0263
# Epoch 4/5
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 20s 26ms/step - accuracy: 0.9855 - loss: 0.0444 - val_accuracy: 0.9918 - val_loss: 0.0238
# Epoch 5/5
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 15s 27ms/step - accuracy: 0.9898 - loss: 0.0338 - val_accuracy: 0.9927 - val_loss: 0.0218
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Adversarially trained model saved to models/mnist_adv_trained_model.h5
# Adversarially trained model - Test accuracy: 0.9927
# Testing adversarially trained model against FGSM attack...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Attack success rate against adversarially trained model: 0.0612
#
# 4.2 Implementing Input Preprocessing defense...
# Training model with Gaussian noise preprocessing...
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 15s 30ms/step - accuracy: 0.8343 - loss: 0.5507 - val_accuracy: 0.9809 - val_loss: 0.0625
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.9761 - loss: 0.0795 - val_accuracy: 0.9838 - val_loss: 0.0508
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - accuracy: 0.9834 - loss: 0.0547 - val_accuracy: 0.9885 - val_loss: 0.0338
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 13s 28ms/step - accuracy: 0.9874 - loss: 0.0417 - val_accuracy: 0.9888 - val_loss: 0.0349
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - accuracy: 0.9899 - loss: 0.0330 - val_accuracy: 0.9880 - val_loss: 0.0336
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Gaussian noise preprocessing model saved to models/mnist_gaussian_noise_model.h5
# Gaussian noise preprocessing model - Test accuracy: 0.9893
# Testing Gaussian noise preprocessing model against FGSM attack...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Attack success rate against Gaussian noise preprocessing model: 0.0408
#
# 4.3 Implementing Ensemble defense...
# Building ensemble from diverse models...
# Ensemble model - Test accuracy: 0.9916
# Testing ensemble model against FGSM attack...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Attack success rate against ensemble model: 0.0707
#
# 5. Comparing all defenses...
#
# Test Accuracy:
# Basic model:                    0.9895
# Adversarially trained model:    0.9927
# Gaussian noise defense model:   0.9893
# Ensemble model:                 0.9916
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# FGSM Attack Success Rate (epsilon=0.1) - LOWER IS BETTER:
# Basic model: 0.1111
# Adversarially trained model: 0.0612
# Gaussian noise defense model: 0.0408
# Ensemble model: 0.0707
# 6. Testing models against different attack strengths...
#
# Testing with epsilon = 0.01
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# Testing with epsilon = 0.05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
# Testing with epsilon = 0.1
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
# Testing with epsilon = 0.2
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# Testing with epsilon = 0.3
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 7. Conclusion
# ================================================================================
# This notebook demonstrated:
# 1. Implementation of the FGSM adversarial attack against an MNIST classifier
# 2. Three defense strategies:
#    - Adversarial Training: Including adversarial examples in training data
#    - Input Preprocessing: Adding Gaussian noise as a defensive measure
#    - Ensemble Defense: Combining multiple models for improved robustness
#
# Findings:
# - The basic model was highly vulnerable to adversarial examples
# - All defense strategies improved robustness to varying degrees
# - Adversarial training provided the most consistent defense across different attack strengths
# - The ensemble approach combined the strengths of individual defenses
# ================================================================================
